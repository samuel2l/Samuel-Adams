# %% [markdown]
# # SAMUEL ADAMS-10949889

# %% [markdown]
# import pandas as pd

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/sadam/Downloads/project.csv")

# %%
df
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
# checking if there are null cells within the data
print(df.isnull().sum())
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
#finding the mean of the various columns in the dataset
ph_avg= df.pH.mean()
quality_avg= df.quality.mean()
density_avg= df.density.mean()

# line above is doing the same with different syntax because it consists of two words
# if done the normal way it results in an error
chlorides_avg = df.chlorides.mean()
citric_acid= df['citric acid'].mean()
total_S02= df['total sulfur dioxide'].mean()

# %%
# inserting the mean into the null spaces
df.pH = df.pH.fillna(ph_avg)
df.density = df.density.fillna(density_avg) 
df.quality = df.quality.fillna(quality_avg)
df.chlorides = df.chlorides.fillna(chlorides_avg)
df['citric acid'] = df['citric acid'].fillna(citric_acid)
df['fixed acidity'] = df['fixed acidity'].fillna(fixed_acidity)
df['free sulfur dioxide'] =df['free sulfur dioxide'].fillna(free_S02)
df['total sulfur dioxide'] =df['total sulfur dioxide'].fillna(total_S02)

# %%
df
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density        pH  \
# ...

# %%
# checking all null values have been filled using mean
print(df.isnull().sum())
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    1
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# error in previous code where some columns are not null because I forgot to add certain columns to be filled, my bad.
# code below verifies that all null cells have now been filled
print(df.isnull().sum())
# Out:
# ID                      0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# describe basically gives data about your data. eg mean,count etc.
df.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %%
#importing libraries to help in drawing of some graphs
import numpy as num
import matplotlib.pyplot as mat
import seaborn as s

# %%
mat.figure(figsize=(10,8))
q= df.corr()
s.heatmap(q, annot=True, cmap='flag')
# Out:
# <Axes: >

# %%
# Histogram of the density column 
mat.figure(figsize=(10,7)) # set the figure size
mat.hist(df['density'])
mat.xlabel('density')
mat.ylabel('frequency')
mat.title('Density Distribution')
# Out:
# Text(0.5, 1.0, 'Density Distribution')

# %%
# Boxplot of another column: free sulphur dioxide
# for variety in the different representations
mat.figure(figsize=(8,6)) # set the figure size
mat.boxplot(x=df['free sulfur dioxide'])
mat.title('Boxplot free sulfur dioxide')
mat.ylabel('free sulfur dioxide')
mat.show()

# %%
df.plot(kind='bar', x='free sulfur dioxide', y='total sulfur dioxide')

mat.title('Bar Chart of free sulfur dioxide against total sulfur dioxide ')
mat.xlabel('free sulfur dioxide')
mat.ylabel('total sulfur dioxide')
mat.xticks(rotation=30)

mat.show()

# %%
 #Scatterplot on fixed acidity and ph
    # color again blue for consistency
mat.figure(figsize=(10,7)) 
mat.scatter(x=df['fixed acidity'], y=df['pH'], s=10, c='blue', alpha=0.5)
#to control line width , color and transparency
mat.title('Scatterplot of Alcohol vs Volatile Acidity')
mat.xlabel('Alcohol')
mat.ylabel('Volatile Acidity')
mat.show()

# %%
df.corr() # to show the correlation betweeen the columns
# Out:
#                             ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.000000      -0.267899         -0.009544    -0.153294
# fixed acidity        -0.267899       1.000000         -0.255557     0.670856
# volatile acidity     -0.009544      -0.255557          1.000000    -0.552909
# citric acid          -0.153294       0.670856         -0.552909     1.000000
# residual sugar       -0.031589       0.114595          0.001877     0.143517
# chlorides            -0.119131       0.093472          0.060748     0.203981
# free sulfur dioxide   0.091145      -0.152932         -0.010591    -0.061252
# total sulfur dioxide -0.113809      -0.113325          0.076247     0.036014
# density              -0.368725       0.667693          0.022753     0.364104
# pH                    0.135082      -0.682452          0.235182    -0.542637
# sulphates            -0.124243       0.182291         -0.261364     0.312839
# ...

# %% [markdown]
# ####  After analyzing this correlation you can tell that  fixed acidity and citric acid have strong correlation. The strongest of course occur when a colmn is crossed with itself(1). In conclusion data cleaning is very important to important make decisions, remove errors in data and overall concurrency of that data
